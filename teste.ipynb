# %%
import pandas as pd
df = pd.read_excel("Data/vendedores.xlsx", index_col=False)
dfString = df.to_string()

# %%
df
# Out:
#    Nome do Vendedor Data da Ultima Venda  Valor da Venda  \
# 0         Ana Silva           2023-09-05            1500
# 1         Ana Silva           2023-09-22            1750
# 2         Ana Silva           2023-10-10            2000
# 3         Ana Silva           2023-10-25            2200
# 4         Ana Silva           2023-11-05            1800
# 5         Ana Silva           2023-11-20            1900
# 6      Carlos Souza           2023-09-15            2500
# 7      Carlos Souza           2023-09-28            2650
# 8      Carlos Souza           2023-10-15            2700
# 9      Carlos Souza           2023-10-29            2850
# 10     Carlos Souza           2023-11-12            3000
# 11     Carlos Souza           2023-11-25            3200
# 12    Fernanda Lima           2023-09-10            3500
# 13    Fernanda Lima           2023-09-20            3600
# 14    Fernanda Lima           2023-10-05            4000
# ...
